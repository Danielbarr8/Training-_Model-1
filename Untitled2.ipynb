# %% [markdown]
# <a href="https://colab.research.google.com/github/Danielbarr8/Training-_Model-1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# Generate random data and labels
data = np.random.rand(100, 10, 1)
labels = np.random.randint(2, size=(100, 1))

# Save data and labels to files
np.save('data.npy', data)
np.save('labels.npy', labels)

# Generate random test data and labels
test_data = np.random.rand(20, 10, 1)
test_labels = np.random.randint(2, size=(20, 1))

# Save test data and labels to files
np.save('test_data.npy', test_data)
np.save('test_labels.npy', test_labels)

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Load data
data = np.load('data.npy')
labels = np.load('labels.npy')

# Split data into training and validation sets
train_data, val_data, train_labels, val_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

# Define LSTM model with increased number of units
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=128, input_shape=(10, 1)),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# Compile the model with a different optimizer
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with increased epochs and decreased batch size
batch_size = 16
epochs = 100
history = model.fit(train_data, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(val_data, val_labels), verbose=1)

# Evaluate the model on validation set
val_loss, val_accuracy = model.evaluate(val_data, val_labels, verbose=0)

# Print the model's accuracy on validation set
print("Validation accuracy: {:.2f}%".format(val_accuracy * 100))

# Evaluate the model on test set
test_data = np.load('test_data.npy')
test_labels = np.load('test_labels.npy')
test_loss, test_accuracy = model.evaluate(test_data, test_labels, verbose=0)

# Print the model's accuracy on test set
print("Test accuracy: {:.2f}%".format(test_accuracy * 100))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 4s 276ms/step - loss: 0.6987 - accuracy: 0.4250 - val_loss: 0.6998 - val_accuracy: 0.3500
# Epoch 2/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6952 - accuracy: 0.4750 - val_loss: 0.6965 - val_accuracy: 0.3500
# Epoch 3/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6981 - accuracy: 0.5000 - val_loss: 0.6978 - val_accuracy: 0.3500
# Epoch 4/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6941 - accuracy: 0.5000 - val_loss: 0.6966 - val_accuracy: 0.3500
# Epoch 5/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6945 - accuracy: 0.4750 - val_loss: 0.6962 - val_accuracy: 0.3500
# Epoch 6/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6952 - accuracy: 0.4875 - val_loss: 0.6956 - val_accuracy: 0.3500
# Epoch 7/100
# ...
